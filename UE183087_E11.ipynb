# %% [markdown]
# ### UE183087
#
# Compare following classifier on Iris, digits and boston dataset of sklearn: Calculate accuracy of following classifiers
#
#  KNeighborsClassifier(3),     SVC(kernel="linear", C=0.025),     SVC(gamma=2, C=1),     GaussianProcessClassifier(1.0 * RBF(1.0)),     DecisionTreeClassifier(max_depth=5),     RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),     MLPClassifier(alpha=1),     AdaBoostClassifier(),     GaussianNB(),     QuadraticDiscriminantAnalysis()]

# %%
import random
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

#defining Given Values
classifiers = [KNeighborsClassifier(3),  
            SVC(kernel="linear", C=0.025),  
            SVC(gamma=2, C=1), 
            GaussianProcessClassifier(1.0 * RBF(1.0)),
            DecisionTreeClassifier(max_depth=5), 
            RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
            MLPClassifier(alpha=1),  
            AdaBoostClassifier(), 
            GaussianNB(),  
            QuadraticDiscriminantAnalysis()]

# %% [markdown]
# *** ACCURACY OF MODELS ON IRIS DATASET

# %%
print('ACCURACY OF MODELS ON DIGITS DATASET')
print('-:')
iris = datasets.load_iris()
X = iris.data
y = iris.target
X_train, test_A, train_A, y_test = train_test_split(A, B, test_size=0.4, random_state=4)

for clf in classifiers:
    clf.fit(train_B, train_A)
    y_pred = clf.predict(test_A)
    print(clf)
    print('Accuracy:', metrics.accuracy_score(y_test, y_pred), '\n')
# Out:
# ACCURACY OF MODELS ON IRIS DATASET
# -:
# KNeighborsClassifier(n_neighbors=3)
# Accuracy: 0.9666666666666667
#
# SVC(C=0.025, kernel='linear')
# Accuracy: 0.95
#
# SVC(C=1, gamma=2)
# Accuracy: 0.9833333333333333
#
# GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1))
# Accuracy: 0.9666666666666667
#
# DecisionTreeClassifier(max_depth=5)
# Accuracy: 0.9666666666666667
#
# RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10)
# Accuracy: 0.9666666666666667
#
# MLPClassifier(alpha=1)
# Accuracy: 0.9666666666666667
#
# AdaBoostClassifier()
# Accuracy: 0.9333333333333333
#
# GaussianNB()
# Accuracy: 0.9666666666666667
#
# QuadraticDiscriminantAnalysis()
# Accuracy: 0.9833333333333333
#
# C:\Sahil\DMA\Programs\Python\Python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
***ACCURACY OF MODELS ON DIGITS DATASET

# %%
print('ACCURACY OF MODELS ON DIGITS DATASET')
print('-:')

digits = datasets.load_digits()

X = digits.data
y = digits.target
X_train, test_A, train_A, y_test = train_test_split(A, B, test_size=0.4, random_state=4)

for clf in classifiers:
    clf.fit(train_B, train_A)
    y_pred = clf.predict(test_A)
    print(clf)
    print('Accuracy:', metrics.accuracy_score(y_test, y_pred), '\n')
# Out:
# ACCURACY OF MODELS ON DIGITS DATASET
# -:
# KNeighborsClassifier(n_neighbors=3)
# Accuracy: 0.9833101529902643
#
# SVC(C=0.025, kernel='linear')
# Accuracy: 0.9777468706536857
#
# SVC(C=1, gamma=2)
# Accuracy: 0.09318497913769123
#
# GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1))
# Accuracy: 0.09874826147426982
#
# DecisionTreeClassifier(max_depth=5)
# Accuracy: 0.6592489568845619
#
# RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10)
# Accuracy: 0.8136300417246175
#
# C:\Sahil\DMA\Programs\Python\Python38-32\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(alpha=1)
# Accuracy: 0.9763560500695411
#
# AdaBoostClassifier()
# Accuracy: 0.23087621696801114
#
# GaussianNB()
# Accuracy: 0.8692628650904033
#
# QuadraticDiscriminantAnalysis()
# Accuracy: 0.9248956884561892
#
# ...

# %%
***ACCURACY OF MODELS ON BOSTON DATASET

# %%
from sklearn import preprocessing
from sklearn import utils

print('ACCURACY OF MODELS ON BOSTON DATASET')
print('-:')

boston = datasets.load_boston()
X = boston.data
y = boston.target
X_train, test_A, train_A, y_test = train_test_split(A, B, test_size=0.4, random_state=4)

lab_enc = preprocessing.LabelEncoder()
enc_y_train = lab_enc.fit_transform(train_A)
enc_y_test = lab_enc.fit_transform(y_test)

for clf in classifiers:
    try:
        clf.fit(train_B, enc_y_train)
        y_pred = clf.predict(test_A)
        print(clf)
        print('Accuracy:', metrics.accuracy_score(enc_y_test, y_pred), '\n')
    except:
        print('error')
        pass
# Out:
# ACCURACY OF MODELS ON BOSTON DATASET
# -:
# KNeighborsClassifier(n_neighbors=3)
# Accuracy: 0.024630541871921183
#
# SVC(C=0.025, kernel='linear')
# Accuracy: 0.024630541871921183
#
# SVC(C=1, gamma=2)
# Accuracy: 0.0049261083743842365
#
# C:\Sahil\DMA\Programs\Python\Python38-32\lib\site-packages\sklearn\gaussian_process\kernels.py:411: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__length_scale is close to the specified upper bound 100000.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1))
# Accuracy: 0.0049261083743842365
#
# DecisionTreeClassifier(max_depth=5)
# Accuracy: 0.014778325123152709
#
# RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10)
# Accuracy: 0.019704433497536946
#
# ...
